# %% [markdown]
# # Python Programming basics

# %% [markdown]
# ## Types and Functions

# %% [markdown]
# Extend the function to take an optional 3rd argument.

# %% [markdown]
# Extend the function to take another optional flag parameter and add only if it is true

# %%
def add(x, y):
  return x+y
   

def add(x, y, z):
  return x+y+z

def add(x, y, z, flag=None):
  if flag:
    print("Flag is true")
  else:  
    return x+y+z



    #ADD YOUR CODE HERE


print(add(2,3,4))
# Out:
# 9

# %% [markdown]
# Assign a function to a variable 'a' and print the output

# %%
a = add(2,3,7)

print(a)
# Out:
# 12

# %% [markdown]
# ## Iterations in python

# %% [markdown]
# Create a list of 5 elements

# %% [markdown]
# Square every item in the list using a loop inside the array index

# %% [markdown]
# Show how to use a iterator. First, use enumerate to create a new tuple from above list

# %%
# creating a list of 5 elements and Squaring every item in the list using a loop inside the array index
num=[4,5,6,2,7]
result=[]
for i in num:
  sqr=i*i
  result.append(sqr)
  
print(result)
# Out:
# [16, 25, 36, 4, 49]

# %%
# Use of Iterator
nums=[4,5,6,9,2]

ia=iter(nums)

print(next(ia))
print(next(ia))
print(next(ia))
print(next(ia))
print(next(ia))

# use enumerate to create a new tuple from above list
for idx,val in enumerate(nums):
  if idx==0:
     print(tuple(nums))
# Out:
# 4
# 5
# 6
# 9
# 2
# (4, 5, 6, 9, 2)

# %%
#use of a iterator
#iterator- returns numbers that starts with 25 and each and every time it is passed it gets squared.

class MyInit:    #for initialization
  def __iter__(self):
    self.a=1
    return self

  def __next__(self):  # does the operation
    x = self.a
    self.a+
    return x

obj1 = MyInit()
itr = iter(obj1)

print(next(itr))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-c4b3f1a216e3> in <module>()
#      13 itr = iter(obj1)
#      14
# ---> 15 print(next(itr))
#
# <ipython-input-15-c4b3f1a216e3> in __next__(self)
#       7
#       8   def __next__(self):  # does the operation
# ----> 9     x = self.a
#      10     return x
#      11
#
# AttributeError: 'MyInit' object has no attribute 'a'

# %%
#First, use enumerate to create a new tuple from above list
listSequence = ["eat","sleep","repeat"] 
for idx,val in enumerate(listSequence):
  if idx==0:

    print(tuple(listSequence))

#at first Enumerating thro' the list and then iterating thro' the loop with for loop.
#iterating through the enumerate function
enu_obj=enumerate(listSequence)
print(next(enu_obj))
print(next(enu_obj))
print(next(enu_obj))

# iterating through for loop
for i in listSequence:
  print(i)
# Out:
# ('eat', 'sleep', 'repeat')
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')
# eat
# sleep
# repeat

# %% [markdown]
# Now use a zip iterator to do the same.

# %%
# use zip to create a new tuple from above list

listSequences1 = ["eat","sleep","repeat","study"] 
listsequences2 = ["apple","cake","banana","orange"]


zippedlist= zip(listSequences1,listsequences2)
print(tuple(zippedlist))

#at first Enumerating thro' the list and then iterating thro' the loop with for loop.
#iterating through the enumerate function
zipp_obj=zip(listSequences1,listsequences2)
print(next(zipp_obj))
print(next(zipp_obj))
print(next(zipp_obj))

# iterating through for loop
for i in listSequences1:
  print(i)
# Out:
# (('eat', 'apple'), ('sleep', 'cake'), ('repeat', 'banana'), ('study', 'orange'))
# ('eat', 'apple')
# ('sleep', 'cake')
# ('repeat', 'banana')
# eat
# sleep
# repeat
# study

# %% [markdown]
# Now state the differences between a zip and enumerate iterator.

# %% [markdown]
# Python`enumerate()` and `zip()` are built-in functions that can be used on sequences.
#
# `enumerate()` function can be use to iterate over indices and items of a list.
#
# `zip()` function make an iterator that aggregates elements from each of the iterables. In simple words it can be used to iterate over two or more lists in parallel.

# %% [markdown]
# ## Strings in Python

# %% [markdown]
# Open the file poem.txt and print lenght of each line.

# %% [markdown]
# Find sum of each line, mean, median and standard deviation of all lines in the file.

# %% [markdown]
# Count the number of words in the file

# %% [markdown]
# Print the first 1000 characters from poem.txt.

# %% [markdown]
# Print the 3rd to 5th words from the file.

# %%
import pandas as pd
with open('/content/poem.txt','r') as file: 
   
    # reading each line 
    # printing lenght of each line.  
    for line in file:
      f=len(file.readline())
      print(f) 
print('\n')
    #  Finding sum of each line, mean, median and standard deviation of all lines in the file
with open('/content/poem.txt','r') as file:     
    da=[]
    for i in file:
      dl=len(file.readline())
      da.append(dl)

    print(da)  
    daa=pd.DataFrame(da)
    print("Mean of all lines",daa.mean())
    print("Median of all lines",daa.median())
    print("Standard Deviation of all lines",daa.std())
    print('\n')

    #Counting the number of words in the file
with open('/content/poem.txt','r') as file:

  count=0
  for i in file:

    words=i.split(" ")
    count+=len(words)

  
print("Number of words in text file are", count)  
print('\n')
     
     # Printing the first 1000 characters from poem.txt.

print("Printing the first 1000 characters")

with open('/content/poem.txt','r') as file:

  count=0
  for i in file:
    if count<1000:

      for j in i:
        print(j)
        count+=1


print("\n")
print("Printing the 3rd to 5th words from the file")

with open('/content/poem.txt','r') as file:
  count=0
  for i in file:
    words=i.split(" ")
    count+=1
    if count==2 and count<5:
      print(words)
# Out:
# 26
# 23
# 1
# 1
# 1
# 59
# 27
# 21
# 23
# 17
# 10
# 19
# 31
# 27
# 11
# 26
# 50
# 1
# 12
# 17
# 1
# 7
# 49
# 48
# 5
# 1
# 44
# 5
# 1
# 10
# 5
# 1
# 40
# 5
# 1
# 47
# 1
# 26
# 6
# 1
# 18
# 45
# 6
# 1
# 1
# 24
# 5
# 1
# 21
# 5
# 23
# 6
# 21
# 8
# 5
# 1
# 5
# 1
# 16
# 5
# 1
# 46
# 5
# 1
# 35
# 47
# 44
# 41
# 5
# 1
# 17
# 41
# 1
# 19
# 1
# 19
# 50
# 29
# 5
# 1
# 1
# 47
# 5
# 1
# 46
# 5
# 1
# 22
# 5
# 1
# 49
# 39
# 1
# 16
# 5
# 1
# 41
# 14
# 5
# 1
# 45
# 21
# 5
# 37
# 1
# 25
# 5
# 35
# 44
# 14
# 5
# 46
# 5
# 43
# 1
# 48
# 42
# 40
# 42
# 49
# 1
# 12
# 41
# 44
# 52
# 35
# 44
# 42
# 49
# 48
# 46
# 38
# 41
# 45
# 40
# 43
# 5
# 46
# 44
# 5
# 42
# 50
# 49
# 46
# 47
# 38
# 37
# 1
# 1
# 41
# 39
# 13
# 39
# 38
# 52
# 52
# 5
# 1
# 26
# 5
# 1
# 11
# 5
# 1
# 1
# 34
# 6
# 1
# 33
# 43
# 5
# 1
# 24
# 7
# 1
# 49
# 5
# 1
# 28
# 6
# 1
# 18
# 6
# 1
# 45
# 37
# 6
# 1
# 1
# 22
# 6
# 1
# 44
# 6
# 1
# 17
# 19
# 5
# 1
# 47
# 5
# 1
# 45
# 1
# 20
# 6
# 1
# 51
# 1
# 1
# 40
# 1
# 1
# 44
# 43
# 41
# 44
# 1
# 27
# 1
# 1
# 18
# 6
# 1
# 47
# 18
# 13
# 6
# 38
# 47
# 1
# 1
# 46
# 47
# 47
# 36
# 20
# 5
# 42
# 1
# 18
# 37
# 41
# 49
# 1
# 1
# 1
# 50
# 21
# 5
# 46
# 38
# 49
# 1
# 1
# 53
# 31
# 16
# 57
# 6
# 1
# 25
# 1
# 44
# 36
# 1
# 21
# 52
# 44
# 1
# 20
# 43
# 48
# 39
# 47
# 44
# 38
# 15
# 6
# 38
# 46
# 1
# 42
# 42
# 28
# 6
# 41
# 51
# 24
# 46
# 1
# 1
# 23
#
#
# [26, 23, 1, 1, 1, 59, 27, 21, 23, 17, 10, 19, 31, 27, 11, 26, 50, 1, 12, 17, 1, 7, 49, 48, 5, 1, 44, 5, 1, 10, 5, 1, 40, 5, 1, 47, 1, 26, 6, 1, 18, 45, 6, 1, 1, 24, 5, 1, 21, 5, 23, 6, 21, 8, 5, 1, 5, 1, 16, 5, 1, 46, 5, 1, 35, 47, 44, 41, 5, 1, 17, 41, 1, 19, 1, 19, 50, 29, 5, 1, 1, 47, 5, 1, 46, 5, 1, 22, 5, 1, 49, 39, 1, 16, 5, 1, 41, 14, 5, 1, 45, 21, 5, 37, 1, 25, 5, 35, 44, 14, 5, 46, 5, 43, 1, 48, 42, 40, 42, 49, 1, 12, 41, 44, 52, 35, 44, 42, 49, 48, 46, 38, 41, 45, 40, 43, 5, 46, 44, 5, 42, 50, 49, 46, 47, 38, 37, 1, 1, 41, 39, 13, 39, 38, 52, 52, 5, 1, 26, 5, 1, 11, 5, 1, 1, 34, 38, 5, 1, 41, 43, 42, 39, 36, 5, 45, 44, 50, 41, 5, 44, 41, 38, 46, 1, 44, 1, 1, 1, 1, 34, 6, 45, 37, 41, 46, 42, 51, 41, 45, 38, 43, 46, 43, 46, 40, 43, 45, 41, 40, 33, 1, 46, 6, 1, 1, 46, 53, 42, 45, 1, 15, 48, 41, 48, 6, 1, 46, 40, 1, 44, 40, 5, 1, 45, 5, 1, 42, 37, 52, 1, 25, 7, 38, 5, 43, 40, 40, 47, 43, 1, 51, 47, 36, 37, 42, 40, 39, 47, 42, 47, 39, 42, 45, 39, 38, 44, 7, 48, 5, 1, 37, 42, 44, 51, 1, 1, 44, 38, 41, 42, 48, 40, 45, 44, 46, 44, 45, 53, 36, 42, 42, 48, 42, 5, 1, 27, 1, 47, 5, 46, 1, 16, 5, 46, 5, 1, 36, 38, 37, 1, 46, 5, 43, 5, 1, 49, 41, 38, 5, 1, 27, 5, 1, 39, 1, 40, 5, 1, 31, 5, 1, 34, 37, 1, 28, 5, 39, 50, 42, 44, 38, 37, 44,
38, 42, 5, 1, 24, 1, 14, 5, 43, 36, 40, 41, 45, 44, 42, 5, 34, 46, 45, 1, 43, 18, 5, 46, 50, 41, 45, 44, 10, 1, 32, 57, 6, 43, 44, 42, 53, 38, 50, 39, 40, 38, 7, 43, 40, 39, 30, 5, 46, 18, 6, 46, 17, 6, 1, 45, 43, 1, 44, 1, 10, 57, 18, 5, 23, 6, 1, 44, 40, 38, 35, 6, 1, 42, 1, 45, 17, 43, 1, 39, 1, 25, 48, 26, 1, 43, 43, 40, 41, 42, 38, 39, 45, 40, 44, 40, 1, 18, 38, 48, 1, 1, 31, 38, 48, 50, 43, 17, 7, 1, 36, 43, 43, 41, 41, 47, 45, 59, 60, 9, 1, 30, 5, 9, 35, 29, 66, 66, 48, 47, 1, 17, 1, 25, 6, 1, 49, 41, 43, 44, 48, 45, 46, 46, 39, 48, 21, 6, 1, 24, 5, 39, 1, 17, 5, 35, 46, 1, 27, 5, 19, 7, 1, 46, 40, 36, 1, 16, 7, 1, 34, 1, 1, 1, 1, 19, 5, 1, 37, 5, 1, 39, 5, 1, 60, 1, 27, 5, 31, 5, 1, 63, 1, 66, 64, 15, 5, 1, 29, 5, 1, 43, 5, 60, 64, 61, 1, 63, 1, 15, 5, 63, 66, 17, 5, 66, 1, 24, 5, 1, 1, 45, 5, 1, 1, 18, 5, 1, 60, 1, 42, 6, 45, 5, 1, 18, 5, 9, 6, 1, 55, 1, 50, 5, 61, 8, 6, 1, ...
# Mean of all lines 0    25.633087
# dtype: float64
# Median of all lines 0    25.0
# dtype: float64
# Standard Deviation of all lines 0    21.074072
# dtype: float64
#
#
# Number of words in text file are 33612
#
#
# Printing the first 1000 characters
# ﻿
# X
# X
# X
# X
#
#
# H
# A
# M
# L
# E
# T
# ,
#
# P
# R
# I
# N
# C
# E
#
# O
# F
#
# D
# E
# N
# M
# A
# R
# K
#
#
#
#
# b
# y
#
# W
# i
# l
# l
# i
# a
# m
#
# S
# h
# a
# k
# e
# s
# p
# e
# a
# r
# e
#
#
#
#
#
#
#
#
#
#
# P
# E
# R
# S
# O
# N
# S
#
# R
# E
# P
# R
# E
# S
# E
# N
# T
# E
# D
# .
#
#
#
#
# C
# l
# a
# u
# d
# i
# u
# s
# ,
#
# K
# i
# n
# g
#
# o
# f
#
# D
# e
# n
# m
# a
# r
# k
# .
#
#
# H
# a
# m
# l
# e
# t
# ,
#
# S
# o
# n
#
# t
# o
#
# t
# h
# e
#
# f
# o
# r
# m
# e
# r
# ,
#
# a
# n
# d
#
# N
# e
# p
# h
# e
# w
#
# t
# o
#
# t
# h
# e
#
# p
# r
# e
# s
# e
# n
# t
#
# K
# i
# n
# g
# .
#
#
# P
# o
# l
# o
# n
# i
# u
# s
# ,
#
# L
# o
# r
# d
#
# C
# h
# a
# m
# b
# e
# r
# l
# a
# i
# n
# .
#
#
# H
# o
# r
# a
# t
# i
# o
# ,
#
# F
# r
# i
# e
# n
# d
#
# t
# o
#
# H
# a
# m
# l
# e
# t
# .
#
#
# L
# a
# e
# r
# t
# e
# s
# ,
#
# S
# o
# n
#
# t
# o
#
# P
# o
# l
# o
# n
# i
# u
# s
# .
#
#
# V
# o
# l
# t
# i
# m
# a
# n
# d
# ,
#
# C
# o
# u
# r
# t
# i
# e
# r
# .
#
#
# C
# o
# r
# n
# e
# l
# i
# u
# s
# ,
#
# C
# o
# u
# r
# t
# i
# e
# r
# .
#
#
# R
# o
# s
# e
# n
# c
# r
# a
# n
# t
# z
# ,
#
# C
# o
# u
# r
# t
# i
# e
# r
# .
#
#
# G
# u
# i
# l
# d
# e
# n
# s
# t
# e
# r
# n
# ,
#
# C
# o
# u
# r
# t
# i
# e
# r
# .
#
#
# O
# s
# r
# i
# c
# ,
#
# C
# o
# u
# r
# t
# i
# e
# r
# .
#
#
# A
#
# G
# e
# n
# t
# l
# e
# m
# a
# n
# ,
#
# C
# o
# u
# r
# t
# i
# e
# r
# .
#
#
# A
#
# P
# r
# i
# e
# s
# t
# .
#
#
# M
# a
# r
# c
# e
# l
# l
# u
# s
# ,
#
# O
# f
# f
# i
# c
# e
# r
# .
#
#
# B
# e
# r
# n
# a
# r
# d
# o
# ,
#
# O
# f
# f
# i
# c
# e
# r
# .
#
#
# F
# r
# a
# n
# c
# i
# s
# c
# o
# ,
#
# a
#
# S
# o
# l
# d
# i
# e
# r
#
#
# R
# e
# y
# n
# a
# l
# d
# o
# ,
#
# S
# e
# r
# v
# a
# n
# t
#
# t
# o
#
# P
# o
# l
# o
# n
# i
# u
# s
# .
#
#
# P
# l
# a
# y
# e
# r
# s
# .
#
#
# T
# w
# o
#
# C
# l
# o
# w
# n
# s
# ,
#
# G
# r
# a
# v
# e
# -
# d
# i
# g
# g
# e
# r
# s
# .
#
#
# F
# o
# r
# t
# i
# n
# b
# r
# a
# s
# ,
#
# P
# r
# i
# n
# c
# e
#
# o
# f
#
# N
# o
# r
# w
# a
# y
# .
#
#
# A
#
# C
# a
# p
# t
# a
# i
# n
# .
#
#
# E
# n
# g
# l
# i
# s
# h
#
# A
# m
# b
# a
# s
# s
# a
# d
# o
# r
# s
# .
#
#
# G
# h
# o
# s
# t
#
# o
# f
#
# H
# a
# m
# l
# e
# t
# '
# s
#
# F
# a
# t
# h
# e
# r
# .
#
#
#
#
# G
# e
# r
# t
# r
# u
# d
# e
# ,
#
# Q
# u
# e
# e
# n
#
# o
# f
#
# D
# e
# n
# m
# a
# r
# k
# ,
#
# a
# n
# d
#
# M
# o
# t
# h
# e
# r
#
# o
# f
#
# H
# a
# m
# l
# e
# t
# .
#
#
# O
# p
# h
# e
# l
# i
# a
# ,
#
# D
# a
# u
# g
# h
# t
# e
# r
#
# t
# o
#
# P
# o
# l
# o
# n
# i
# u
# s
# .
#
#
#
#
# L
# o
# r
# d
# s
# ,
#
# L
# a
# d
# i
# e
# s
# ,
#
# O
# f
# f
# i
# c
# e
# r
# s
# ,
#
# S
# o
# l
# d
# i
# e
# r
# s
# ,
#
# S
# a
# i
# l
# o
# r
# s
# ,
#
# M
# e
# s
# s
# e
# n
# g
# e
# r
# s
# ,
#
# a
# n
# d
#
# o
# t
# h
# e
# r
#
#
# A
# t
# t
# e
# n
# d
# a
# n
# t
# s
# .
#
#
#
#
# S
# C
# E
# N
# E
# .
#
# E
# l
# s
# i
# n
# o
# r
# e
# .
#
#
#
#
#
#
#
#
# A
# C
# T
#
# I
# .
#
#
#
#
# S
# c
# e
# n
# e
#
# I
# .
#
# E
# l
# s
# i
# n
# o
# r
# e
# .
#
# A
#
# p
# l
# a
# t
# f
# o
# r
# m
#
# b
# e
# f
# o
# r
# e
#
# t
# h
# e
#
# C
# a
# s
# t
# l
# e
# .
#
#
#
#
# [
# F
# r
# a
# n
# c
# i
# s
# c
# o
#
# a
# t
#
# h
# i
# s
#
# p
# o
# s
# t
# .
#
# E
# n
# t
# e
# r
#
# t
# o
#
# h
# i
# m
#
# B
# e
# r
# n
# a
# r
# d
# o
# .
# ]
#
#
#
#
# B
# e
# r
# .
#
#
# W
# h
# o
# '
# s
#
# t
# h
# e
# r
# e
# ?
#
#
#
#
# F
# r
# a
# n
# .
#
#
# N
# a
# y
# ,
#
# a
# n
# s
# w
# e
# r
#
# m
# e
# :
#
# s
# t
# a
# n
# d
# ,
#
# a
# n
# d
#
# u
# n
# f
# o
# l
# d
#
# y
# o
# u
# r
# s
# e
# l
# f
# .
#
#
#
#
# B
# e
# r
# .
#
#
# L
# o
# n
# g
#
# l
# i
# v
# e
#
# t
# h
# e
#
# k
# i
# n
# g
# !
#
#
#
#
# F
# r
# a
# n
# .
#
#
# B
# e
# r
# n
# a
# r
# d
# o
# ?
#
#
#
#
# Printing the 3rd to 5th words from the file
# ['HAMLET,', 'PRINCE', 'OF', 'DENMARK\n']

# %% [markdown]
# Get every third word between the second and the 15th words from poem.txt.

# %% [markdown]
# Print the last word from the file and change the second last characted in the string to 'g'.

# %% [markdown]
# State if the above operation completed successfully. State reasons

# %% [markdown]
# # Find types of Python variables and functions

# %% [markdown]
# Find what are the types of the following and state if they are mutable of immutable

# %%
print(type(None))
print(type(1))
print(type(1.0))
print(type('add'))
(1,'a',3,'b')   # It is the tuple which is immutable
list_name=[1,'a',3,'b'] # It is the list which is mutable
# Out:
# <class 'NoneType'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# Append new elements at the end of a list

# %% [markdown]
# Loop through each element of the list

# %% [markdown]
# Use a indexing operator

# %%
#indexing operator
# Appending the list
str_indexing = ["Vivek","Sachin","Jatin","Jayant","Parikshit"]
str_indexing.append('Prince')
print(str_indexing)
print('\n')

# printing each element through loop
for i in str_indexing:
  print(i)

print('\n')

# Use a index operator
print(str_indexing.index('Vivek'))
print(str_indexing[2])
print(str_indexing[3:])
print(str_indexing[0:5])
# Out:
# ['Vivek', 'Sachin', 'Jatin', 'Jayant', 'Parikshit', 'Prince']
#
#
# Vivek
# Sachin
# Jatin
# Jayant
# Parikshit
# Prince
#
#
# 0
# Jatin
# ['Jayant', 'Parikshit', 'Prince']
# ['Vivek', 'Sachin', 'Jatin', 'Jayant', 'Parikshit']

# %% [markdown]
# Concatenate two lists

# %%
# concatenating the two list
list1=["Vivek","Sachin","Jatin","Jayant","Parikshit"]
list2=[3,4,6,7,8]
list3=list1 + list2
print(list3)
# Out:
# ['Vivek', 'Sachin', 'Jatin', 'Jayant', 'Parikshit', 3, 4, 6, 7, 8]

# %% [markdown]
# Use * to repeat lists

# %%
listname=[2,3,5,7,8,5,2,8,9,12]
listname1=listname*5
print(listname1)
# Out:
# [2, 3, 5, 7, 8, 5, 2, 8, 9, 12, 2, 3, 5, 7, 8, 5, 2, 8, 9, 12, 2, 3, 5, 7, 8, 5, 2, 8, 9, 12, 2, 3, 5, 7, 8, 5, 2, 8, 9, 12, 2, 3, 5, 7, 8, 5, 2, 8, 9, 12]

# %% [markdown]
# Use the in operator to check if something is in a list

# %%
x8=[2,3,5,7,8,9]
for i in x8:
  if i>4:
    print(i)
# Out:
# 5
# 7
# 8
# 9

# %% [markdown]
# Initialize a string and slice the first 1, 2 and 3 characters. Then from 3rd to end.

# %%
str_x="VIVEK"
print(str_x[0:3])
print(str_x[3:])
# Out:
# VIV
# EK

# %% [markdown]
# Take a first name and a last name and then concatenate the last name with 3 times the first name and show result.

# %%
first_name=["Vivek"]
last_name=["Kumar"]
full_name=first_name + last_name*3
print(full_name)
# Out:
# ['Vivek', 'Kumar', 'Kumar', 'Kumar']

# %% [markdown]
# Take a string with four words. Use the split function to display the second and the last words

# %%
str_name=('My name is Vivek')
words=str_name.split(" ")
print(words[1])
print(words[3])
# Out:
# name
# Vivek

# %% [markdown]
# Concatenate a number with a string. Update following:

# %%
numb=24
str_p= "My name is Vivek"
str_cocat=str(numb) + str_p
print(str_cocat)
# Out:
# 24My name is Vivek

# %% [markdown]
# ## Dictionaries associated with lists

# %% [markdown]
# Create a list of keys and values

# %%
Days_conversions={
    "Sun": "Sunday",
    "Mon": "Monday",
    "Tue": "Tuesday",
    "Wed": "Wednesday",
    "Thur": "Thursday",
    "Fri": "Friday",
    "Sat": "Saturday"
}

# %% [markdown]
# Iterate over all the keys

# %%
for i in Days_conversions.keys():
  print(Days_conversions[i])
# Out:
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday

# %% [markdown]
# Iterate over all the values

# %%
for i in Days_conversions.values():
  print([i])
# Out:
# ['Sunday']
# ['Monday']
# ['Tuesday']
# ['Wednesday']
# ['Thursday']
# ['Friday']
# ['Saturday']

# %% [markdown]
# Iterate over all the key-value pairs in the list

# %%
for i in (Days_conversions.keys(),Days_conversions.values()):

  print(i)
# Out:
# dict_keys(['Sun', 'Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat'])
# dict_values(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'])

# %% [markdown]
# Unpack the following sequence into different variables

# %%
(Name,College,Email,Branch)=('Prithwish','IIITG','prithwish.sen@iiitg','CSE')
print((Name,College,Email,Branch))
# Out:
# ('Prithwish', 'IIITG', 'prithwish.sen@iiitg', 'CSE')

# %% [markdown]
# Use Python's in-built methods for string formatting

# %%
sales_record = {
'price': 3.24,
'num_items': 4,
'person': 'Prithwish',
'total': 12.96
}

sales_statement = ('{} got {} item(s) at a cost of {} each for a total of {}'.format(sales_record['person'],sales_record['num_items'],sales_record['price'],sales_record['total']))
print(sales_statement)
# Out:
# Prithwish got 4 item(s) at a cost of 3.24 each for a total of 12.96

# %% [markdown]
# Take a list of 10 elements and convert into json using  json library. Demonstrate use of loads and dumps

# %%
Data_list={
    'Name':'Vivek',
    'College':'MNNIT',
    'Place':'Prayagraj',
    'Branch':'Chemical',
    'Gender':'Male',
    'Status':'Unmarried',
    'age':21,
    'price': 3.24,
    'num_items': 4,
    'person': 'Prithwish',
    'total': 12.96
}

print(json.dumps(Data_list))
# Out:
# {"Name": "Vivek", "College": "MNNIT", "Place": "Prayagraj", "Branch": "Chemical", "Gender": "Male", "Status": "Unmarried", "age": 21, "price": 3.24, "num_items": 4, "person": "Prithwish", "total": 12.96}

# %% [markdown]
# # Python objects and functions

# %% [markdown]
# Take the following code:

# %%
class students:
    dept = "Department of CSE"
    def assign_name(self, name):
        self.name = name
    def assign_location(self, location):
        self.location = location

p=students("Vivek","Ghaziabad")
print(p.name)
print(p.students)

# %% [markdown]
# Create a object of the class above. Set name and location of your choice.

# %% [markdown]
# Format accordingly and print in a manner so we see something like : "Dip Sankar lives in Guwahati, Assam, India and works in the Department of CSE". The name and location should be of your choice. Use 1 print only

# %%
sentence = ('{} lives in {} and is a student in the {}'.format('Dip Sankar','Guwahati','Motoilal Nehru National Institute Of Technology'))
print(sentence)
# Out:
# Dip Sankar lives in Guwahati and is a student in the Motoilal Nehru National Institute Of Technology

# %% [markdown]
# Create two lists of 5 elements each. Map the min function to the lists using map(). Print the minimum object.

# %%
list_num=[2,4,5,7,3]
list_name=[9,8,2,7,1]


list_new=list(map(lambda x,y:min(x,y),list_num,list_name))
print(list_new)
# Out:
# [2, 4, 2, 7, 1]

# %% [markdown]
# Iterate through that object and print the elements.

# %%
for i in list_new:
  print(i)
# Out:
# 2
# 4
# 2
# 7
# 1

# %% [markdown]
# # Working with CSV

# %% [markdown]
# Let's import a file with fuel economy data

# %%
import pandas as pd

df=pd.read_csv('/content/mpg.csv')
df
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  ...  drv cty hwy  fl    class
# 0             1         audi      a4    1.8  1999  ...    f  18  29   p  compact
# 1             2         audi      a4    1.8  1999  ...    f  21  29   p  compact
# 2             3         audi      a4    2.0  2008  ...    f  20  31   p  compact
# 3             4         audi      a4    2.0  2008  ...    f  21  30   p  compact
# 4             5         audi      a4    2.8  1999  ...    f  16  26   p  compact
# ..          ...          ...     ...    ...   ...  ...  ...  ..  ..  ..      ...
# 229         230   volkswagen  passat    2.0  2008  ...    f  19  28   p  midsize
# 230         231   volkswagen  passat    2.0  2008  ...    f  21  29   p  midsize
# 231         232   volkswagen  passat    2.8  1999  ...    f  16  26   p  midsize
# 232         233   volkswagen  passat    2.8  1999  ...    f  18  26   p  midsize
# 233         234   volkswagen  passat    3.6  2008  ...    f  17  26   p  midsize
#
# [234 rows x 12 columns]

# %% [markdown]
# Find out how many items are there in the dictionary

# %%
df.count()
# Out:
# Unnamed: 0      234
# manufacturer    234
# model           234
# displ           234
# year            234
# cyl             234
# trans           234
# drv             234
# cty             234
# hwy             234
# fl              234
# class           234
# dtype: int64

# %% [markdown]
# Find the column names with keys

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'manufacturer', 'model', 'displ', 'year', 'cyl', 'trans',
#        'drv', 'cty', 'hwy', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# Find the average cty fuel economy across all cars. All values in the dictionaries are strings.

# %%
x=df['cty'].mean()
x
# Out:
# 16.858974358974358

# %% [markdown]
# Find the average hwy fuel economy across all cars

# %%
y=df['hwy'].mean()
y
# Out:
# 23.44017094017094

# %% [markdown]
# Use set to return the unique values for the number of cylinders the cars.

# %%
cylinders = set(df['cyl'])
print(cylinders)
# Out:
# {8, 4, 5, 6}

# %% [markdown]
# Group the cars by number of cylinder, and finding the average cty mpg for each group.

# %%
z = df.groupby(["manufacturer","cyl"])["cty"].mean()
df_name = pd.DataFrame(z)
df_name
# Out:
#                         cty
# manufacturer cyl
# audi         4    19.125000
#              6    16.444444
#              8    16.000000
# chevrolet    4    20.500000
#              6    17.666667
#              8    13.642857
# dodge        4    18.000000
#              6    15.000000
#              8    11.571429
# ford         6    15.300000
#              8    13.133333
# honda        4    24.444444
# hyundai      4    19.500000
#              6    17.500000
# jeep         6    15.666667
#              8    12.200000
# land rover   8    11.500000
# lincoln      8    11.333333
# mercury      6    13.500000
#              8    13.000000
# nissan       4    21.500000
#              6    17.125000
#              8    12.000000
# pontiac      6    17.250000
#              8    16.000000
# subaru       4    19.285714
# toyota       4    20.888889
#              6    16.615385
#              8    12.666667
# volkswagen   4    22.470588
#              5    20.500000
#              6    16.833333

# %%
MpgByCyl = []

for c in cylinders: # iterate over all the cylinder levels
    summpg = 
    typecount = 
    for d in mpg: # iterate over all dictionaries
        if d['cyl'] == c:      

MpgByCyl.sort(key=lambda)
MpgByCyl
# Out:
# [('4', 21.012345679012345),
#  ('5', 20.5),
#  ('6', 16.21518987341772),
#  ('8', 12.571428571428571)]

# %%
w = df.groupby(df["cyl"])["trans"].count()
df_name32 = pd.DataFrame(w)
df_name32
# Out:
#      trans
# cyl
# 4       81
# 5        4
# 6       79
# 8       70

# %% [markdown]
# Return the unique values for the class types in our dataset using set.

# %%
df['class'].unique()
# Out:
# array(['compact', 'midsize', 'suv', '2seater', 'minivan', 'pickup',
#        'subcompact'], dtype=object)

# %% [markdown]
# Find average miles per gallon in the highway for each class of vehicles

# %%
MileageByClass = []

for t in : # iterate over all the vehicle classes
    sumpg = 0
    classCount = 0
    for d in mpg: 
        if d['class'] == t:                 
    MileageByClass.append((t, )) 

MileageByClass.sort(key=lambda x: x[1])

# %%
m= df.groupby(["manufacturer","cyl"])["trans"].count()
df_r = pd.DataFrame(m)
df_r
# Out:
#                   trans
# manufacturer cyl
# audi         4        8
#              6        9
#              8        1
# chevrolet    4        2
#              6        3
#              8       14
# dodge        4        1
#              6       15
#              8       21
# ford         6       10
#              8       15
# honda        4        9
# hyundai      4        8
#              6        6
# jeep         6        3
#              8        5
# land rover   8        4
# lincoln      8        3
# mercury      6        2
#              8        2
# nissan       4        4
#              6        8
#              8        1
# pontiac      6        4
#              8        1
# subaru       4       14
# toyota       4       18
#              6       13
#              8        3
# volkswagen   4       17
#              5        4
#              6        6
